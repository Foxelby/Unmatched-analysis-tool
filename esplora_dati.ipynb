# %%
import pandas as pd

# %%
df=pd.read_csv("vrwwh747l.csv")

# %%
df
# Out:
#            category  Achilles  Alice  Ancient Leshen  Angel  Angel - Alt 1.0  \
# 0          Achilles        -2     29              52      0               -2
# 1             Alice        71     -2              50      0               -2
# 2    Ancient Leshen        48     50              -2      0               -2
# 3             Angel       100    100             100     -2               -2
# 4   Angel - Alt 1.0        -2     -2              -2     -2               -2
# ..              ...       ...    ...             ...    ...              ...
# 79            Triss        44     -2              33     -2               -2
# 80           Willow        67    100              -2     50               -2
# 81   Winter Soldier        75     57              63     -2               -2
# 82         Yennefer        59      0              44      0               -2
# 83         Yennenga        42     38              16      0               -2
#
# ...
